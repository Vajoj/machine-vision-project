# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load image
img = cv2.imread("Training_Data/example.jpg")  # Replace with your actual image path

### **Step 1: Preprocessing**
# Convert to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

# Apply Gaussian blur to reduce noise
blurred = cv2.GaussianBlur(gray, (5, 5), 0)

# Perform edge detection (Increase lower threshold to suppress thin edges)
edges = cv2.Canny(blurred, 150, 300)

# Perform morphological operations
kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (5,5))  # Use elliptical kernel
eroded = cv2.erode(edges, None, iterations=2)  # Suppress thin features (wires) earlier
dilated = cv2.dilate(eroded, None, iterations=1)  # Strengthen resistor body, but avoid expanding wires
opened = cv2.morphologyEx(dilated, cv2.MORPH_OPEN, kernel)  # Removes remaining thin objects like wires
contours, _ = cv2.findContours(opened, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

### **Step 2: Contour Detection and Filtering**
contours, _ = cv2.findContours(eroded, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Iterate through detected contours
for cnt in contours:
    hull = cv2.convexHull(cnt)
    hull_area = cv2.contourArea(hull)

    x, y, w, h = cv2.boundingRect(cnt)
    aspect_ratio = w / float(h)
    area = cv2.contourArea(cnt)
    perimeter = cv2.arcLength(cnt, True)
    solidity = float(area) / hull_area  # Compute solidity

    # Ignore highly elongated and thin objects
    if hull_area / area > 0.85:
        continue
    if solidity < 0.6:
        continue
    if aspect_ratio < 0.5 or aspect_ratio > 3.5:
        continue
    if w < 25 or h < 15:
        continue

    # Draw bounding box for detected resistor
    cv2.rectangle(img, (x, y), (x+w, y+h), (0, 255, 0), 2)


### **Step 3: Color Classification for Resistor Bands**
# Convert to HSV for color segmentation
img_hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)

# Define HSV color ranges for resistor bands
color_ranges = {
    'black': [(0, 0, 0), (180, 255, 50)],
    'brown': [(10, 100, 20), (20, 255, 200)],
    'red': [(0, 100, 100), (10, 255, 255)],
    'orange': [(10, 100, 100), (25, 255, 255)],
    'yellow': [(25, 100, 100), (35, 255, 255)],
    'green': [(35, 100, 100), (85, 255, 255)],
    'blue': [(85, 100, 100), (130, 255, 255)],
    'violet': [(130, 50, 50), (160, 255, 255)],
    'grey': [(0, 0, 50), (180, 50, 200)],
    'white': [(0, 0, 200), (180, 30, 255)],
    'gold': [(15, 100, 100), (45, 200, 200)],
    'silver': [(0, 0, 100), (180, 30, 200)],
}



### **Step 4: Visualization**
# Show edge detection result
plt.imshow(edges, cmap='gray')
plt.title("Edge Detection")
plt.show()

cv2.drawContours(img, [cnt], -1, (0, 0, 255), 1)  # Red = filtered contours

# Show detected resistor with bounding boxes
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))  # Convert for proper display
plt.title("Detected Resistor")
plt.show()

# Debug color segmentation: Display color masks to verify resistor bands
for color, (lower, upper) in color_ranges.items():
    mask = cv2.inRange(img_hsv, np.array(lower), np.array(upper))
    plt.imshow(mask, cmap='gray')
    plt.title(f"{color} Mask")
    plt.show()
